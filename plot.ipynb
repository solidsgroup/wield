# %%
import matplotlib.pyplot as plt
import numpy as np

# plot
thetas, gbes = np.loadtxt('111-110atgb.txt', delimiter = ' ', unpack = True)

#print(thetas)

plt.plot(thetas, gbes)
plt.xlabel('Tilt Angle (deg)')
plt.ylabel('GB Energy (J/m)')
plt.title('Grain Boundary Energy')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-1fc1e3d1b38e> in <module>()
#       3
#       4 # plot
# ----> 5 thetas, gbes = np.loadtxt('111-110atgb.txt', delimiter = ' ', unpack = True)
#       6
#       7 #print(thetas)
#
# /home/mgokuli/.local/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     960             fname = os_fspath(fname)
#     961         if _is_string_like(fname):
# --> 962             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     963             fencoding = getattr(fh, 'encoding', 'latin1')
#     964             fh = iter(fh)
#
# /home/mgokuli/.local/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     264
#     265     ds = DataSource(destpath)
# ...
