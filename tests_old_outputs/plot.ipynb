# %%
import matplotlib.pyplot as plt
import numpy as np

# plot

thetas, gbes = np.loadtxt('113-110atgb_Spt25_try_exact_same.txt', delimiter = ' ', unpack = True)

#print(thetas)

plt.plot(thetas, gbes)
plt.xlabel('Tilt Angle (deg)')
plt.ylabel('GB Energy (J/m)')
plt.title('Grain Boundary Energy')
plt.show()

# %%
ax = plt.subplot(111, projection='polar')
ax.plot(thetas * np.pi / 180, gbes)
ax.set_rticks([0.7, 0.8])
ax.set_theta_offset(np.pi/2)

ax.set_title("113-110atgb_sigma-pt25", va='bottom')
plt.show()
